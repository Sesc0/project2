# %% [markdown]
# # Predicting Percent Change of the Dow

# %% [markdown]
# ### Initial Imports & Setting today's Date

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import quandl
from pathlib import Path
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import yfinance as yf
from datetime import date
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression, HuberRegressor, SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import preprocessing, utils, tree
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_squared_log_error
from sklearn.model_selection import RepeatedKFold, cross_val_score
from prophet import Prophet
import plotly.express as px
import plotly.graph_objects as go
import lightgbm as ltb
pd.options.plotting.backend = "plotly"
import seaborn as sns
from matplotlib import pyplot
# Needed for decision tree visualization
import pydotplus
from IPython.display import Image

yf.pdr_override()

#setting today's date
today = date.today()

# %% [markdown]
# ### Gathering the data

# %%
# getting the data

# 10 Year note
us_treasury = quandl.get("USTREASURY/YIELD")
us_treasury = us_treasury['10 YR'].to_frame()

# gold prices
gold = quandl.get("LBMA/GOLD")
gold = gold['USD (AM)']
gold = gold.to_frame()
gold.rename(columns={'USD (AM)':'Gold Value'}, inplace=True)

# emerging markets high yield corporate bond index yield
emerging_markets_high_yield_corporate_bond_index_yield = quandl.get("ML/EMHYY", authtoken="yJcjsffiR2vsG79sQqj1")
emerging_markets_high_yield_corporate_bond_index_yield.rename(columns={'BAMLEMHBHYCRPIEY':'Emerging Markets HYCBIY Value'}, inplace=True)

# s&p 500 inflation adjusted
sp_500_inflation_adjusted = quandl.get("MULTPL/SP500_INFLADJ_MONTH", authtoken="yJcjsffiR2vsG79sQqj1")
sp_500_inflation_adjusted.rename(columns={'Value':'S&P Inflation Adjusted'}, inplace=True)

# personal consumption expenditures
personal_consumption_expenditures = quandl.get("FRED/PCE")
personal_consumption_expenditures.rename(columns={'Value':'PCE Value'}, inplace=True)

# dow jones

dow = pdr.get_data_yahoo("^DJI", start="1980-01-01", end=today)
dow = dow['Close'].to_frame()
dow.rename(columns={'Close':'Dow Value'}, inplace=True)

df = pd.concat([us_treasury,gold,emerging_markets_high_yield_corporate_bond_index_yield,sp_500_inflation_adjusted,personal_consumption_expenditures,dow],
               join = 'inner', axis='columns')
df = df.pct_change().dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                10 YR  Gold Value  Emerging Markets HYCBIY Value  \
# 1999-03-01  0.136842   -0.000174                      -0.028840
# 1999-04-01 -0.024074   -0.022818                      -0.076824
# 1999-06-01  0.096774   -0.053476                      -0.027273
# 1999-07-01  0.012111   -0.009416                      -0.027318
# 1999-09-01  0.023932   -0.028707                       0.008869
# ...              ...         ...                            ...
# 2020-10-01  0.000000   -0.046480                       0.076807
# 2020-12-01  0.352941   -0.052412                      -0.153846
# 2021-02-01  0.184783    0.034295                      -0.056198
# 2021-03-01  0.330275   -0.059667                       0.003503
# 2021-04-01  0.165517   -0.017802                       0.038394
#
#             S&P Inflation Adjusted  PCE Value  Dow Value
# 1999-03-01                0.025025   0.005097  -0.002238
# 1999-04-01                0.033912   0.010321   0.054449
# 1999-06-01               -0.009149   0.009328   0.077676
# 1999-07-01                0.041057   0.004397   0.044370
# 1999-09-01               -0.052312   0.015490  -0.011615
# ...                            ...        ...        ...
# 2020-10-01                0.015382   0.003045  -0.028931
# 2020-12-01                0.080553  -0.012032   0.072151
# 2021-02-01                0.040762   0.022344   0.013009
# 2021-03-01               -0.000111   0.050176   0.043811
# 2021-04-01                0.050354   0.009094   0.051298
#
# [166 rows x 6 columns]

# %% [markdown]
# ### Splitting & Scaling the data

# %%
#Declaring X & Y
X = df.drop(columns=['Dow Value'])
y = df['Dow Value'].to_frame()

# Splitting Data
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=42,shuffle=False)

# Scaling Data
scaler = StandardScaler()

# Fitting the training data to the model
X_scaler = scaler.fit(X_train)

# Scaling the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# ### Fitting the data

# %%
# Logistic Regression Model
regr = LinearRegression()
regr.fit(X_train, y_train)

predictions = regr.predict(X_test)

# %% [markdown]
# ### Coefficients

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.10f' % mean_squared_error(y_test, predictions))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_test, predictions))
# Out:
# Coefficients:
#  [[ 0.12371411 -0.02131856 -0.11050374  0.5346154   0.39337618]]
# Mean squared error: 0.0009784604
# Coefficient of determination: 0.71

# %% [markdown]
# ### Plotting the data

# %%
test = pd.DataFrame({"Prediction": list(predictions), "Actual": list(y_test.values)}).set_index(y_test.index)
fig, ax = plt.subplots()
fig.set_figwidth(30)
fig.set_figheight(15)
line1 = ax.plot(test['Prediction'], label="Prediction")
line2 = ax.plot(test['Actual'], label = 'Actual')
ax.set_ylabel('Percent Change', fontsize=18)
ax.set_xlabel('Year', fontsize=18)
ax.set_title('Linear Regression Model', fontsize=32)
#plt.plot(test)
plt.xticks(rotation = 45, fontsize=16)
plt.yticks(rotation = 45, fontsize=16)
#plt.style.use("Solarize_Light2")
plt.legend()
plt.savefig('Linear Regression Model.png')

# %% [markdown]
# ### Linear Regression Feature Importance

# %%
regr_importance = regr.coef_.flatten()
plt.figure(figsize=(25,20))
plt.bar([x for x in range(len(regr_importance))], regr_importance)
plt.suptitle('Linear Regression Feature importance',fontsize=32)
plt.xlabel("Features",fontsize=18)
plt.xticks([0,1,2,3,4],['10 YR','Gold Value','Emerging Markets HYCBIY Value','S&P Inflation Adjusted','PCE Value'],fontsize=16)
plt.ylabel('Feature Importance',fontsize=18)
plt.yticks(fontsize=16)
plt.savefig('Linear Regression Feature importance.png',dpi=400)
plt.show()

# %% [markdown]
# ## Decision Tree Regressor Model

# %% [markdown]
# ### Fitting the data

# %%
# Fitting the decision tree
model = tree.DecisionTreeRegressor()
model = model.fit(X_train_scaled, y_train)

# Making predictions
predictions = model.predict(X_test_scaled)

# %% [markdown]
# ### Coefficients

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.10f' % mean_squared_error(y_test, predictions))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% r2_score(y_test, predictions))
# Out:
# Coefficients:
#  [[ 0.12371411 -0.02131856 -0.11050374  0.5346154   0.39337618]]
# Mean squared error: 0.0026835746
# Coefficient of determination: 0.21

# %% [markdown]
# ### Plotting the data

# %%
test_tree = pd.DataFrame({"Prediction": list(predictions), "Actual": list(y_test.values)}).set_index(y_test.index)
fig, ax = plt.subplots()
fig.set_figwidth(30)
fig.set_figheight(15)
line1 = ax.plot(test_tree['Prediction'], label="Prediction")
line2 = ax.plot(test_tree['Actual'], label = 'Actual')
ax.set_ylabel('Percent Change', fontsize=18)
ax.set_xlabel('Year', fontsize=18)
ax.set_title('Decision Tree Model', fontsize=32)
#plt.plot(test)
plt.xticks(rotation = 45, fontsize=16)
plt.yticks(rotation = 45, fontsize=16)
#plt.style.use("Solarize_Light2")
plt.legend()
plt.savefig('Decision Tree Model.png')

# %% [markdown]
# ### Decision Tree Feature Importance

# %%
model_importance = model.feature_importances_
plt.figure(figsize=(25,20))
plt.bar([x for x in range(len(model_importance))], model_importance)
plt.suptitle('Decision Tree Regression Feature importance',fontsize=32)
plt.xlabel("Features",fontsize=18)
plt.xticks([0,1,2,3,4],['10 YR','Gold Value','Emerging Markets HYCBIY Value','S&P Inflation Adjusted','PCE Value'],fontsize=16)
plt.ylabel('Feature Importance',fontsize=18)
plt.yticks(fontsize=16)
plt.savefig('Decision Tree Regression Feature importance.png',dpi=400)
plt.show()

# %% [markdown]
# LGBM Regressor# LGBM Regressor

# %% [markdown]
# ### Fitting the data

# %%
lgbm = ltb.LGBMRegressor()
lgbm.fit(X_train_scaled, y_train.values.ravel())
print(); print(model)
predictions = model.predict(X_test_scaled)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Coefficients

# %%
print(f"R-squared: %.10f" % r2_score(y_test, predictions))
print(f"Mean Squared Error: %.10f" % mean_squared_error(y_test, predictions))
# Out:
# R-squared: 0.3022915873
# Mean Squared Error: 0.0023840321

# %% [markdown]
# ### Plotting the data

# %%
plt.figure(figsize=(20,20))
sns.regplot(y_test, predictions, fit_reg=True, scatter_kws={"s": 100})
plt.savefig('LGBM Regression.png')
# Out:
# C:\Users\Sebs1\anaconda3\envs\dev\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
lgbm_importance = lgbm.feature_importances_
plt.figure(figsize=(25,20))
plt.bar([x for x in range(len(lgbm_importance))], lgbm_importance)
plt.suptitle('LGBM Regressor Feature Importance',fontsize=32)
plt.xlabel("Features",fontsize=18)
plt.xticks([0,1,2,3,4],['10 YR','Gold Value','Emerging Markets HYCBIY Value','S&P Inflation Adjusted','PCE Value'],fontsize=16)
plt.ylabel('Feature Importance',fontsize=18)
plt.yticks(fontsize=16)
plt.savefig('LGBM Regressor Feature Importance.png',dpi=400)
plt.show()

# %% [markdown]
# # SGD Regressor

# %% [markdown]
# ### Fitting the data

# %%
sgdr = SGDRegressor()
sgdr.fit(X_train_scaled, y_train.values.ravel())
ypred = sgdr.predict(X_test_scaled)

# %% [markdown]
# ### Coefficients

# %%
score = sgdr.score(X_train_scaled, y_train)
print("R-squared:", score)
cv_score = cross_val_score(sgdr, X_train_scaled, y_train.values.ravel(), cv = 10)
print("CV mean score: ", cv_score.mean())
mse = mean_squared_error(y_test, ypred)
print("MSE: ", mse)
print("RMSE: ", mse*(1/2.0))
# Out:
# R-squared: 0.5695707806375424
# CV mean score:  0.4429863863960376
# MSE:  0.001231887138807379
# RMSE:  0.0006159435694036895

# %% [markdown]
# ### Plotting the data

# %%
test = pd.DataFrame({"Prediction": list(ypred), "Actual": list(y_test.values)}).set_index(y_test.index)
x_ax = range(len(y_test))
fig, ax = plt.subplots()
fig.set_figwidth(30)
fig.set_figheight(15)
line1 = ax.plot(test['Prediction'], label="Prediction")
line2 = ax.plot(test['Actual'], label = 'Actual')
#plt.plot(test)
plt.xticks(rotation = 45)
ax.set_ylabel('Percent Change', fontsize=18)
ax.set_xlabel('Year', fontsize=18)
ax.set_title('SGD Regressor', fontsize=32)
plt.legend()
fig.savefig('SGD Regressor.png')

# %%
sgdr_importance = sgdr.coef_
plt.figure(figsize=(25,20))
plt.bar([x for x in range(len(sgdr_importance))], sgdr_importance)
plt.suptitle('SGD Regression Feature importance',fontsize=32)
plt.xlabel("Features",fontsize=18)
plt.xticks([0,1,2,3,4],['10 YR','Gold Value','Emerging Markets HYCBIY Value','S&P Inflation Adjusted','PCE Value'],fontsize=16)
plt.ylabel('Feature Importance',fontsize=18)
plt.yticks(fontsize=16)
plt.savefig('SGD Regression Feature importance.png',dpi=400)
plt.show()
