# %%
import pandas as pd
import quandl
from pathlib import Path
import matplotlib.pyplot as plt
from full_fred.fred import Fred

# %%
path = r"C:\Users\Sebs1\Downloads\Dow Jones Industrial Average Historical Data.xlsx"
api_keys = r"fred api key.txt"

# %%
fred = Fred(api_keys)
fred.get_api_key_file()
# Out:
# 'fred api key.txt'

# %%
dow = fred.get_series_df('DJIA').set_index('date')
dow.value = dow.value.replace(to_replace='.')
dow.value = dow.value.apply(lambda x: float(x))
dow
# Out:
#            realtime_start realtime_end     value
# date
# 2011-07-08     2021-07-08   2021-07-08  12657.20
# 2011-07-11     2021-07-08   2021-07-08  12505.76
# 2011-07-12     2021-07-08   2021-07-08  12446.88
# 2011-07-13     2021-07-08   2021-07-08  12491.61
# 2011-07-14     2021-07-08   2021-07-08  12437.12
# ...                   ...          ...       ...
# 2021-07-01     2021-07-08   2021-07-08  34633.53
# 2021-07-02     2021-07-08   2021-07-08  34786.35
# 2021-07-05     2021-07-08   2021-07-08  34786.35
# 2021-07-06     2021-07-08   2021-07-08  34577.37
# 2021-07-07     2021-07-08   2021-07-08  34681.79
#
# [2609 rows x 3 columns]

# %%
emerging_markets_high_yield_corporate_bond_index_yield
# Out:
#             Emerging Markets HYCBIY Value
# DATE
# 1998-12-31                          14.92
# 1999-01-04                          14.90
# 1999-01-05                          14.89
# 1999-01-06                          14.79
# 1999-01-07                          14.78
# ...                                   ...
# 2021-07-01                           5.91
# 2021-07-02                           5.92
# 2021-07-05                           5.92
# 2021-07-06                           6.01
# 2021-07-07                           5.99
#
# [5880 rows x 1 columns]

# %%
stock_market_confidence_indices = quandl.get("YALE/US_CONF_INDEX_CRASH_INST")
us_treasury_long_term_rates = quandl.get("USTREASURY/REALLONGTERM", authtoken="yJcjsffiR2vsG79sQqj1")
emerging_markets_high_yield_corporate_bond_index_yield = quandl.get("ML/EMHYY", authtoken="yJcjsffiR2vsG79sQqj1")
united_kingdom_spot_exchange_rate = quandl.get("FED/RXI_US_N_A_UK", authtoken="yJcjsffiR2vsG79sQqj1")
dji = quandl.get("BCB/UDJIAD1")
treasury_real_yield_curve_rates = quandl.get("USTREASURY/REALYIELD", authtoken="yJcjsffiR2vsG79sQqj1")
sp_500_inflation_adjusted = quandl.get("MULTPL/SP500_INFLADJ_MONTH", authtoken="yJcjsffiR2vsG79sQqj1")
personal_consumption_expenditures = quandl.get("FRED/PCE")
gold = quandl.get("BOE/XUMAGPD")

# %%
us_treasury = quandl.get("USTREASURY/YIELD")
us_treasury = us_treasury['10 YR']

# %%
stock_market_confidence_indices = stock_market_confidence_indices['Index Value'].to_frame()

# %%
us_treasury
# Out:
#             10 YR
# Date
# 1990-01-02   7.94
# 1990-01-03   7.99
# 1990-01-04   7.98
# 1990-01-05   7.99
# 1990-01-08   8.02
# ...           ...
# 2021-07-01   1.48
# 2021-07-02   1.44
# 2021-07-06   1.37
# 2021-07-07   1.33
# 2021-07-08   1.30
#
# [7886 rows x 1 columns]

# %%
 us_treasury = us_treasury.to_frame()

# %%
df_all = pd.concat([stock_market_confidence_indices,us_treasury,gold,personal_consumption_expenditures,sp_500_inflation_adjusted,united_kingdom_spot_exchange_rate,us_treasury_long_term_rates,emerging_markets_high_yield_corporate_bond_index_yield,dow2])
df_all
# Out:
#             Index Value  10 YR  Gold Value  PCE Value  SPY Value  \
# 1989-10-31        36.99    NaN         NaN        NaN        NaN
# 1990-04-30        25.76    NaN         NaN        NaN        NaN
# 1990-10-31        18.25    NaN         NaN        NaN        NaN
# 1991-04-30        31.58    NaN         NaN        NaN        NaN
# 1991-10-31        37.18    NaN         NaN        NaN        NaN
# ...                 ...    ...         ...        ...        ...
# 2016-04-11          NaN    NaN         NaN        NaN        NaN
# 2016-04-12          NaN    NaN         NaN        NaN        NaN
# 2016-04-13          NaN    NaN         NaN        NaN        NaN
# 2016-04-14          NaN    NaN         NaN        NaN        NaN
# 2016-04-15          NaN    NaN         NaN        NaN        NaN
#
#             USD/UK Value  LT Real Average (>10Yrs)  \
# 1989-10-31           NaN                       NaN
# 1990-04-30           NaN                       NaN
# 1990-10-31           NaN                       NaN
# 1991-04-30           NaN                       NaN
# 1991-10-31           NaN                       NaN
# ...                  ...                       ...
# 2016-04-11           NaN                       NaN
# 2016-04-12           NaN                       NaN
# 2016-04-13           NaN                       NaN
# 2016-04-14           NaN                       NaN
# 2016-04-15           NaN                       NaN
#
#             Emerging Markets HYCBIY Value     Value
# 1989-10-31                            NaN       NaN
# 1990-04-30                            NaN       NaN
# 1990-10-31                            NaN       NaN
# 1991-04-30                            NaN       NaN
# 1991-10-31                            NaN       NaN
# ...                                   ...       ...
# 2016-04-11                            NaN  17556.41
# 2016-04-12                            NaN  17721.25
# 2016-04-13                            NaN  17908.28
# 2016-04-14                            NaN  17926.43
# 2016-04-15                            NaN  17897.46
#
# [55094 rows x 9 columns]

# %%
personal_consumption_expenditures.rename(columns={"Value":"PCE Value"},inplace=True)
gold.rename(columns={"Value":"Gold Value"},inplace=True)
sp_500_inflation_adjusted.rename(columns={'Value':'SPY Value'},inplace=True)
united_kingdom_spot_exchange_rate.rename(columns={'SPY Value':'USD/UK Value'},inplace=True)
emerging_markets_high_yield_corporate_bond_index_yield.rename(columns={'BAMLEMHBHYCRPIEY':'Emerging Markets HYCBIY Value'},inplace=True)
emerging_markets_high_yield_corporate_bond_index_yield
# Out:
#             Emerging Markets HYCBIY Value
# DATE
# 1998-12-31                          14.92
# 1999-01-04                          14.90
# 1999-01-05                          14.89
# 1999-01-06                          14.79
# 1999-01-07                          14.78
# ...                                   ...
# 2021-07-01                           5.91
# 2021-07-02                           5.92
# 2021-07-05                           5.92
# 2021-07-06                           6.01
# 2021-07-07                           5.99
#
# [5880 rows x 1 columns]

# %%
stock_market_confidence_indices['Index Value'].plot(figsize = (10,10))
treasury_real_yield_curve_rates.plot(figsize = (10,10))
sp_500_inflation_adjusted.plot(figsize = (10,10))
personal_consumption_expenditures.plot(figsize = (10,10))
gold.plot(figsize = (10,10))
us_treasury_long_term_rates.plot(figsize = (10,10))
sp_500_inflation_adjusted.plot(figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
p = "Personal Consumption Expenditures".replaceto_frame).lower()
p
# Out:
# 'personal_consumption_expenditures'

# %%
p
# Out:
# 'personal_consumption_expenditures'

# %%
dow.value.plot(figsize = (20,20))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dow
# Out:
#            realtime_start realtime_end     value
# date
# 2011-07-08     2021-07-08   2021-07-08  12657.20
# 2011-07-11     2021-07-08   2021-07-08  12505.76
# 2011-07-12     2021-07-08   2021-07-08  12446.88
# 2011-07-13     2021-07-08   2021-07-08  12491.61
# 2011-07-14     2021-07-08   2021-07-08  12437.12
# ...                   ...          ...       ...
# 2021-07-01     2021-07-08   2021-07-08  34633.53
# 2021-07-02     2021-07-08   2021-07-08  34786.35
# 2021-07-05     2021-07-08   2021-07-08  34786.35
# 2021-07-06     2021-07-08   2021-07-08  34577.37
# 2021-07-07     2021-07-08   2021-07-08  34681.79
#
# [2609 rows x 3 columns]

# %%
dow2 = quandl.get("BCB/UDJIAD1").pct_change()

# %%
dow2
# Out:
#                Value
# Date
# 1896-07-14       NaN
# 1896-07-15 -0.034400
# 1896-07-16 -0.010223
# 1896-07-17 -0.000313
# 1896-07-18 -0.013776
# ...              ...
# 2016-04-11 -0.001169
# 2016-04-12  0.009389
# 2016-04-13  0.010554
# 2016-04-14  0.001013
# 2016-04-15 -0.001616
#
# [32601 rows x 1 columns]

# %%
dow2["2015":"2016"].plot(figsize=(20,20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
personal_consumption_expenditures.plot(figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='Date'>
